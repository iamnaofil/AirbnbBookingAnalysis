# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnaofil/AirbnbBookingAnalysis/blob/main/PandasTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('contacts.csv')
print(data)
print("\n")
print(type(data))
print("\n")
print(pd.DataFrame(data))
# Out:
#      First Name Last Name    Contacts
# 0        Shahid      Khan  1122445577
# 1  Mohan Sharma       NaN  3322114455
# 2        Hemant  Chaudhry  6655441122
#
#
# <class 'pandas.core.frame.DataFrame'>
#
#
#      First Name Last Name    Contacts
# 0        Shahid      Khan  1122445577
# 1  Mohan Sharma       NaN  3322114455
# 2        Hemant  Chaudhry  6655441122

# %%
import pandas as pd
mydataset={
    'cars':["maruti","hyundai","rangrover"],
    'color':["red","gray","yellow"],
    'speed':[112,124,130]
}
new=pd.DataFrame(mydataset)
print(new)
print(type(new))
#print(type(mydataset)) #This is Commented , prevent from printing
# Out:
#         cars   color  speed
# 0     maruti     red    112
# 1    hyundai    gray    124
# 2  rangrover  yellow    130
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
#Accessing Values / Elements
list=[1,3,5,7,9,11]
list_to_series=pd.Series(list)
print(list_to_series[2])
# Out:
# 5

# %%
print(list_to_series[1:3])
# Out:
# 1    3
# 2    5
# dtype: int64

# %%
import pandas as pd
data=["amit","heman","dilip","akshay"]
data_series=pd.Series(data, index=[10,20,30,40])
print(data_series)
# Out:
# 10      amit
# 20     heman
# 30     dilip
# 40    akshay
# dtype: object

# %%
import pandas as pd
data=["amit","heman","dilip","akshay"]
data_series=pd.Series(data, index=["10","20","30","40"])
print(data_series)
print("\n Accessing 20 index as w egive it as string \"\" ")
print(data_series["20"])
# Out:
# 10      amit
# 20     heman
# 30     dilip
# 40    akshay
# dtype: object
#
#  Accessing 20 index as w egive it as string ""
# heman

# %%
import pandas as pd
calories={"Day 1": 2030, "Day 2":1280,"Day 3": 1845,"Day 4":1420,"Day 6":244,"Day 7":890, "Day 8":1190,"Day 9":1050,"Day 10":1675}
#print(calories)
calories_series=pd.Series(calories)
print(calories_series)
# Out:
# Day 1     2030
# Day 2     1280
# Day 3     1845
# Day 4     1420
# Day 6      244
# Day 7      890
# Day 8     1190
# Day 9     1050
# Day 10    1675
# dtype: int64

# %%
max_day=data.idxmax()
max_data=data.loc[max_day]
print(max_data)
# Out:
# 2030

# %%
above_2000=data>2000
print(above_2000)
# Out:
# Day 1      True
# Day 2     False
# Day 3     False
# Day 4     False
# Day 6     False
# Day 7     False
# Day 8     False
# Day 9     False
# Day 10    False
# dtype: bool

# %%
data=calories_series
the_day=data[data==1190].index
print(the_day)
# Out:
# Index(['Day 8'], dtype='object')

# %%
high_cal=calories_series.max()
print(high_cal)
# Out:
# 2030

# %%
days=len(calories_series)
print(days)
# Out:
# 9

# %%
import pandas as pd
my_data={
    "calories":[1200,1450,1200,1320],
    "duration":[30,20,10,30]
    }
print(my_data)
# Out:
# {'calories': [1200, 1450, 1200, 1320], 'duration': [30, 20, 10, 30]}

# %%
df=pd.DataFrame(my_data)
print(df)
# Out:
#    calories  duration
# 0      1200        30
# 1      1450        20
# 2      1200        10
# 3      1320        30

# %%
print(df.loc[0:2])
# Out:
#    calories  duration
# 0      1200        30
# 1      1450        20
# 2      1200        10

# %%
print(df.loc[[1,0,3]])
# Out:
#    calories  duration
# 1      1450        20
# 0      1200        30
# 3      1320        30

# %%
#NAMED INDEX in DataFrame
import pandas as pd
cal={
     "calories":[1200,1450,1200,1320],
    "duration":[30,20,10,30]
      }
data=pd.DataFrame(cal,index=["Day 1","Day2", "Day 3","Day 4"])
print(data.loc["Day 1"])

# %%
print(data.loc[["Day 3","Day2","Day 1"]])
# Out:
#        calories  duration
# Day 3      1200        10
# Day2       1450        20
# Day 1      1200        30

# %%
import pandas as pd
data=pd.read_csv('contacts.csv')
print(data)
# Out:
#      First Name Last Name    Contacts
# 0        Shahid      Khan  1122445577
# 1  Mohan Sharma       NaN  3322114455
# 2        Hemant  Chaudhry  6655441122

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      First Name Last Name    Contacts
# 0        Shahid      Khan  1122445577
# 1  Mohan Sharma       NaN  3322114455
# 2        Hemant  Chaudhry  6655441122

# %%
df.loc[1,"First Name"]="Mohan"
print(df)
# Out:
#   First Name Last Name    Contacts
# 0     Shahid      Khan  1122445577
# 1      Mohan       NaN  3322114455
# 2     Hemant  Chaudhry  6655441122

# %%
df.loc[1,"Last Name"]="Sharma"
print(df)
# Out:
#   First Name Last Name    Contacts
# 0     Shahid      Khan  1122445577
# 1      Mohan    Sharma  3322114455
# 2     Hemant  Chaudhry  6655441122

# %%
#Now We have balance_sheet.csv.
import pandas as pd
balance_sheet=pd.read_csv('balance_sheet.csv')
print(balance_sheet.to_string)
# Out:
# <bound method DataFrame.to_string of        Period                         Inst_sector  Inst_sector_code  \
# 0     2007.03  Non-corporate business enterprises               121
# 1     2007.03  Non-corporate business enterprises               121
# 2     2007.03  Non-corporate business enterprises               121
# 3     2007.03  Non-corporate business enterprises               121
# 4     2007.03  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 6550  2021.03                   Total all sectors               900
# 6551  2021.03                   Total all sectors               900
# 6552  2021.03                   Total all sectors               900
# 6553  2021.03                   Total all sectors               900
# 6554  2021.03                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# ...

# %%
df=pd.DataFrame(balance_sheet)
print(df)
# Out:
#        Period                         Inst_sector  Inst_sector_code  \
# 0     2007.03  Non-corporate business enterprises               121
# 1     2007.03  Non-corporate business enterprises               121
# 2     2007.03  Non-corporate business enterprises               121
# 3     2007.03  Non-corporate business enterprises               121
# 4     2007.03  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 6550  2021.03                   Total all sectors               900
# 6551  2021.03                   Total all sectors               900
# 6552  2021.03                   Total all sectors               900
# 6553  2021.03                   Total all sectors               900
# 6554  2021.03                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# 0                          Closing balance total assets    LE00000
# ...

# %%
print(balance_sheet.to_string())
# Out:
#        Period                                                                Inst_sector  Inst_sector_code                                                                                   Descriptor SNA08TRANS Asset_liability_code   Values
# 0     2007.03                                         Non-corporate business enterprises               121                                                                 Closing balance total assets    LE00000              A000000   345973
# 1     2007.03                                         Non-corporate business enterprises               121                    Financial assets Closing balance total financial and non-financial assets    LE00000              AFA0000    99770
# 2     2007.03                                         Non-corporate business enterprises               121                    Financial assets Closing balance monetary gold and special drawing rights    LE00000              AFA0100        0
# ...

# %%
import json
import pandas as pd
df=pd.read_json("data2.js")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-f39a24f090c0> in <cell line: 3>()
#       1 import json
#       2 import pandas as pd
# ----> 3 df=pd.read_json("data2.js")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import json
import pandas as pd
with open("/content/file.json") as f:
  data=json.load(f)

# %%
import pandas as pd
data_json={
    "name": "John Doe",
  "age": 30,
  "email": "john.doe@example.com",
  "address": {
    "street": "123 Main St",
    "city": "New York",
    "country": "USA"
  },
  "interests": ["programming", "reading", "traveling"],
  "is_student": "true"
}
print(data_json)
# Out:
# {'name': 'John Doe', 'age': 30, 'email': 'john.doe@example.com', 'address': {'street': '123 Main St', 'city': 'New York', 'country': 'USA'}, 'interests': ['programming', 'reading', 'traveling'], 'is_student': 'true'}

# %%
import pandas as pd
import json
with open('file.json') as f:
  data=json.load(f)
print(data)

# %%
import pandas as pd
df=pd.read_csv('contacts.csv')
data=pd.DataFrame(df)

#new=data[data.loc[1,]]
#print(df.info())
print(df)
# Out:
#      First Name Last Name    Contacts
# 0        Shahid      Khan  1122445577
# 1  Mohan Sharma       NaN  3322114455
# 2        Hemant  Chaudhry  6655441122

# %%
#Changinge Values DataFrame ki Location Jaha Par row wise 1 aur column name 'FirstName' Ho
data.loc[1,'First Name']="Mohan"
data.loc[1,'Last Name']="Sharma"
print(df)
# Out:
#   First Name Last Name    Contacts
# 0     Shahid      Khan  1122445577
# 1      Mohan    Sharma  3322114455
# 2     Hemant  Chaudhry  6655441122

# %%
df['age']=[25,21,28]

# %%
print(df)
# Out:
#   First Name Last Name    Contacts  age
# 0     Shahid      Khan  1122445577   25
# 1      Mohan    Sharma  3322114455   21
# 2     Hemant  Chaudhry  6655441122   28

# %%
import pandas as pd

# %%
#Cleaning Empty Cells, that potentially gives us wrong result when you analyze

# %%
#Remove Rows: is One way  te deal with Empty Cells. if you have more bigg Data

# %%
import pandas as pd
df=pd.read_csv('DataCol.csv')

# %%
print(df)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories  Unnamed: 5  Unnamed: 6  \
# 0         60  21-01-2023'    110       120     300.0         NaN         NaN
# 1         60  29-05-2023'    117       135     300.2         NaN         NaN
# 2        606  22-01-2023'    103       134     250.6         NaN         NaN
# 3         60   01-05-2023    110       124     230.5         NaN         NaN
# 4         60          NaN     95       103     321.4         NaN         NaN
# 5         60   06-01-2023    100       112     231.2         NaN         NaN
# 6         60   11-02-2023    105       122     653.5         NaN         NaN
# 7         60   07-01-2023     68       100     200.0         NaN         NaN
# 8         60   07-01-2023     68       100     200.0         NaN         NaN
# 9         60   06-05-2023     88       152    1142.5         NaN         NaN
# 10        60   07-05-2023     96       125    1200.0         NaN         NaN
# ...

# %%
df.shape[1]
# Out:
# 16

# %%
#To Delete any Specific Column you can write df.drop(df.columns[4],axis=1)
#BUt If you want to delete from num to num of Column ....
res=df.drop(df.columns[5:16],axis=1)
print(res)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  21-01-2023'    110       120     300.0
# 1         60  29-05-2023'    117       135     300.2
# 2        606  22-01-2023'    103       134     250.6
# 3         60   01-05-2023    110       124     230.5
# 4         60          NaN     95       103     321.4
# 5         60   06-01-2023    100       112     231.2
# 6         60   11-02-2023    105       122     653.5
# 7         60   07-01-2023     68       100     200.0
# 8         60   07-01-2023     68       100     200.0
# 9         60   06-05-2023     88       152    1142.5
# 10        60   07-05-2023     96       125    1200.0
# 11        60   08-05-2023    114       126    1010.0
# 12        60   09-05-2023    102       132    1802.0
# 13        60   10-05-2023    106       124    1350.0
# 14        60   11-05-2023    116       124    2300.0
# 15        60   12-05-2023    121       140       0.0
