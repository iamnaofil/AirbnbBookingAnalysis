# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/Airbnb.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (38824, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.882400e+04  3.882400e+04  38824.000000  38824.000000  38824.000000
# mean   1.809990e+07  6.424289e+07     40.728127    -73.951151    142.330543
# std    1.069383e+07  7.589550e+07      0.054991      0.046692    196.987955
# min    2.539000e+03  2.438000e+03     40.506410    -74.244420      0.000000
# 25%    8.721242e+06  7.029240e+06     40.688640    -73.982470     69.000000
# 50%    1.887229e+07  2.837092e+07     40.721710    -73.954810    101.000000
# 75%    2.756637e+07  1.018856e+08     40.762990    -73.935020    170.000000
# max    3.645581e+07  2.738417e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    38824.000000       38824.000000       38821.000000
# mean         5.869256          29.287992           1.373229
# std         17.388423          48.181726           1.680328
# ...

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 38819  False  False    False      False                False          False
# 38820  False  False    False      False                False          False
# 38821  False  False    False      False                False          False
# 38822  False  False    False      False                False          False
# 38823  False  False    False      False                False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       3
# reviews_per_month                 3
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.fillna(df.mode(), inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'host_id'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>],
#        [<AxesSubplot:title={'center':'number_of_reviews'}>,
#         <AxesSubplot:title={'center':'reviews_per_month'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count'}>],
#        [<AxesSubplot:title={'center':'availability_365'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.show()

# %%
df.plot(kind='scatter', x='latitude', y='longitude', alpha=0.4, figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
df.groupby('neighbourhood_group').price.mean()
# Out:
# neighbourhood_group
# Bronx             79.558857
# Brooklyn         121.457636
# Manhattan        180.072795
# Queens            95.783683
# Staten Island     89.964968
# Name: price, dtype: float64

# %%
#The resulting output shows the average (mean) price of Airbnb listings in each neighbourhood group.
#By grouping the listings by neighbourhood group, you can get a sense of how prices vary between
#different parts of the city. This can be useful for identifying areas that are more expensive
#or more affordable, and for understanding the overall price trends in the market

# %%
import matplotlib.pyplot as plt

df.price.plot(kind='hist', bins=50, figsize=(10,8))
plt.title('Distribution of Airbnb Listing Prices')
plt.xlabel('Price per Night ($)')
plt.show()

# %%
df_city_Manhattan = df[df['neighbourhood_group'] == 'Manhattan']

# %%
avg_price_by_room_type = df_city_Manhattan.groupby('room_type').price.mean()

# %%
avg_price_by_room_type = avg_price_by_room_type.sort_values(ascending=False)

# %%
print("Average price by room type in", df_city_Manhattan, ":")
# Out:
# Average price by room type in              id                                              name    host_id  \
# 1          2595                             Skylit Midtown Castle       2845
# 3          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 4          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5178                  Large Furnished Room Near B'way        8967
# 7          5203                Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                               ...        ...
# 38811  36318560   Luxury Sun-filled Private Room near Time Square   52917571
# 38812  36335990               Sunny Studio steps from Wall Street  269870940
# 38814  36351128  One bedroom without roomies, close to everything  273361532
# 38817  36411407              Brand new 1 bedroom steps from Soho!   33917435
# 38819  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
#
# ...

# %%
print(avg_price_by_room_type)
# Out:
# room_type
# Entire home/apt    230.200964
# Private room       106.622303
# Shared room         77.980337
# Name: price, dtype: float64

# %%
overall_avg_price = df_city_Manhattan.price.mean()

# %%
print("Overall average price for all listings in", df_city_Manhattan, ": $", overall_avg_price)
# Out:
# Overall average price for all listings in              id                                              name    host_id  \
# 1          2595                             Skylit Midtown Castle       2845
# 3          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 4          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5178                  Large Furnished Room Near B'way        8967
# 7          5203                Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                               ...        ...
# 38811  36318560   Luxury Sun-filled Private Room near Time Square   52917571
# 38812  36335990               Sunny Studio steps from Wall Street  269870940
# 38814  36351128  One bedroom without roomies, close to everything  273361532
# 38817  36411407              Brand new 1 bedroom steps from Soho!   33917435
# 38819  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
#
# ...

# %%
# Group by listing id and calculate average rating and number of reviews
df_reviews = df.groupby('id').agg({'number_of_reviews': 'sum', 'review_scores_rating': 'mean'})
# Sort by number of reviews in descending order
df_reviews.sort_values('number_of_reviews', ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18992\4057844792.py in <module>
#       1 # Group by listing id and calculate average rating and number of reviews
# ----> 2 df_reviews = df.groupby('id').agg({'number_of_reviews': 'sum', 'review_scores_rating': 'mean'})
#       3 # Sort by number of reviews in descending order
#       4 df_reviews.sort_values('number_of_reviews', ascending=False, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     867
#     868         op = GroupByApply(self, func, args, kwargs)
# --> 869         result = op.agg()
#     870         if not is_dict_like(func) and result is not None:
#     871             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in agg(self)
#     166
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df_city = df[df['neighbourhood_group'] == 'Manhattan']
popular_room_types = df_city['room_type'].value_counts().head()
avg_price_by_room_type = df_city.groupby('room_type').price.mean().sort_values(ascending=False)

# %%
avg_price_by_room_type
# Out:
# room_type
# Entire home/apt    230.200964
# Private room       106.622303
# Shared room         77.980337
# Name: price, dtype: float64

# %%
reviews_by_listing = df_city.groupby('name').number_of_reviews.sum().sort_values(ascending=False)

# %%
reviews_by_listing
# Out:
# name
# Private Bedroom in Manhattan                 666
# Beautiful Bedroom in Manhattan               617
# Great Bedroom in Manhattan                   607
# Manhattan Lux Loft.Like.Love.Lots.Look !     540
# PRIVATE Room on Historic Sugar Hill          458
#                                             ...
# Amazing, classy, safe & convenient!            1
# Stylish, cozy 1BR in Upper West Manhattan      1
# Private room in shared apartment for 1         1
# Boho escape in Upper Manhattan                 1
# Thanksgiving Vacation                          0
# Name: number_of_reviews, Length: 16419, dtype: int64

# %%
overall_avg_price = df_city['price'].mean()

# %%
overall_avg_price
# Out:
# 180.07279509084347

# %%
avg_price_by_room_type
# Out:
# room_type
# Entire home/apt    230.200964
# Private room       106.622303
# Shared room         77.980337
# Name: price, dtype: float64

# %%
available_listings = df_city[df_city['availability_365'] > 0]

# %%
available_listings
# Out:
#              id                                              name    host_id  \
# 1          2595                             Skylit Midtown Castle       2845
# 4          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5178                  Large Furnished Room Near B'way        8967
# 8          5238                Cute & Cozy Lower East Side 1 bdrm       7549
# 9          5295                  Beautiful 1br on Upper West Side       7702
# ...         ...                                               ...        ...
# 38811  36318560   Luxury Sun-filled Private Room near Time Square   52917571
# 38812  36335990               Sunny Studio steps from Wall Street  269870940
# 38814  36351128  One bedroom without roomies, close to everything  273361532
# 38817  36411407              Brand new 1 bedroom steps from Soho!   33917435
# 38819  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
#
# ...

# %%
reviews_by_listing = df_city.groupby('name').number_of_reviews.sum().sort_values(ascending=False)

# %%
reviews_by_listing
# Out:
# name
# Private Bedroom in Manhattan                 666
# Beautiful Bedroom in Manhattan               617
# Great Bedroom in Manhattan                   607
# Manhattan Lux Loft.Like.Love.Lots.Look !     540
# PRIVATE Room on Historic Sugar Hill          458
#                                             ...
# Amazing, classy, safe & convenient!            1
# Stylish, cozy 1BR in Upper West Manhattan      1
# Private room in shared apartment for 1         1
# Boho escape in Upper Manhattan                 1
# Thanksgiving Vacation                          0
# Name: number_of_reviews, Length: 16419, dtype: int64

# %%
available_listings = df_city[df_city['availability_365'] > 0]

# %%
available_listings
# Out:
#              id                                              name    host_id  \
# 1          2595                             Skylit Midtown Castle       2845
# 4          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5178                  Large Furnished Room Near B'way        8967
# 8          5238                Cute & Cozy Lower East Side 1 bdrm       7549
# 9          5295                  Beautiful 1br on Upper West Side       7702
# ...         ...                                               ...        ...
# 38811  36318560   Luxury Sun-filled Private Room near Time Square   52917571
# 38812  36335990               Sunny Studio steps from Wall Street  269870940
# 38814  36351128  One bedroom without roomies, close to everything  273361532
# 38817  36411407              Brand new 1 bedroom steps from Soho!   33917435
# 38819  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
#
# ...

# %%
plt.hist(available_listings['availability_365'], bins=100)
plt.xlabel('Number of days available')
plt.ylabel('Frequency')
plt.title('Availability of Airbnb listings in Manhattan ')
plt.show()

# %%
plt.scatter(x=available_listings['latitude'], y=available_listings['longitude'], s=0.5)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Map of Available Airbnb Listings')
plt.show()
